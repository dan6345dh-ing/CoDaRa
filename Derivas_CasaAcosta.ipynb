# %%
import oficina as of
import numpy as np
import matplotlib.pyplot as plt
import sys

Coef=0.75
R=1.5

# %%
print("ADMINISTRACION - BLQOUE 4")
Caso=np.array(["Estado Actual","Propuesta"])
Deplazamiento_Nodo_X=np.array([[0.0,0.00112,0.001685,0.001822],[0.0,0.000695,0.001019,0.001184]])
Deplazamiento_Nodo_Y=np.array([[0.0,0.002719,0.004034,0.004298],[0.0,0.00081,0.001244,0.001507]])

Pisos=np.array([0.0,3.0,5.7,7.25])
DerivaX=of.Deriva(Pisos,Deplazamiento_Nodo_X*Coef*R,Caso,1)
plt.title("Sentido X")
DerivaY=of.Deriva(Pisos,Deplazamiento_Nodo_Y*Coef*R,Caso,1)
plt.title("Sentido Y")

print("SENTIDO X", DerivaX)
print("SENTIDO Y", DerivaY)
# Out:
# ADMINISTRACION - BLQOUE 4
# SENTIDO X [[0.         0.042      0.01115132 0.00212586]
#  [0.         0.0260625  0.00639474 0.00256034]]
# SENTIDO Y [[0.         0.1019625  0.02595395 0.00409655]
#  [0.         0.030375   0.00856579 0.00408103]]
# C:\Users\Ing Herrera\Documents\Py-Jora\oficina.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Ing Herrera\Documents\Py-Jora\oficina.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
print("Teatros EA -BLQOUE 2")
Caso=np.array(["Estado Actual","Propuesta"])
Deplazamiento_Nodo_X=np.array([[0.0,0.025],[0.0,0.000343]]) # pico de las paredes
Deplazamiento_Nodo_Y=np.array([[0.0,0.046315],[0.0,0.005481]]) # alto del arco

Pisos=np.array([0.0,4.7])
DerivaX=of.Deriva(Pisos,Deplazamiento_Nodo_X*Coef*R,Caso,1)
plt.title("Sentido X")
Pisos=np.array([0.0,3.5])
DerivaY=of.Deriva(Pisos,Deplazamiento_Nodo_Y*Coef*R,Caso,1)
plt.title("Sentido Y")
print("SENTIDO X", DerivaX)
print("SENTIDO Y", DerivaY)
# Out:
# Teatros EA -BLQOUE 2
# SENTIDO X [[0.         0.59840426]
#  [0.         0.00821011]]
# SENTIDO Y [[0.         1.48869643]
#  [0.         0.176175  ]]
# C:\Users\Ing Herrera\Documents\Py-Jora\oficina.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Ing Herrera\Documents\Py-Jora\oficina.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
print("AULAS -BLOQUE X")
Caso=np.array(["Estado Actual","Propuesta"])
Deplazamiento_Nodo_X=np.array([[0.0,0.036565],[0.0,0]]) # pico de las paredes
Deplazamiento_Nodo_Y=np.array([[0.0,0.026421],[0.0,0.005481]]) # alto del arco

Pisos=np.array([0.0,3.6])
DerivaX=of.Deriva(Pisos,Deplazamiento_Nodo_X*Coef*R,Caso,1)
plt.title("Sentido X")
Pisos=np.array([0.0,3.6])
DerivaY=of.Deriva(Pisos,Deplazamiento_Nodo_Y*Coef*R,Caso,1)
plt.title("Sentido Y")
print("SENTIDO X", DerivaX)
print("SENTIDO Y", DerivaY)
# Out:
# AULAS -BLOQUE X
# SENTIDO X [[0.         1.14265625]
#  [0.         0.        ]]
# SENTIDO Y [[0.         0.82565625]
#  [0.         0.17128125]]
# C:\Users\Ing Herrera\Documents\Py-Jora\oficina.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Ing Herrera\Documents\Py-Jora\oficina.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
